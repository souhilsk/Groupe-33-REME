# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
from IPython.display import display
from tqdm import trange

# %% [markdown]
# ### Canton-Panel DiD
#
# $\text{transformed\_crime\_rate}_{cgt}
# = \beta\,(T_{g}\times P_{t})
# \;+\;FE_{c}
# \;+\;FE_{t}
# \;+\;FE_{g}
# \;+\;\varepsilon_{cgt}.$

# %%
# DiD
df_ct = pd.read_excel("/Users/souhil/Desktop/Courses/Recherche Empirique/Final/Data/cleaned/crimes_subject_to_law_cleaned_by_canton.xlsx")

good = []
for c in df_ct['canton'].unique():
    sub = df_ct[df_ct['canton']==c]
    good.append(c)
df_ct = df_ct[df_ct['canton'].isin(good)].copy()


# prepare DiD variables
df_ct['transformed_CR'] = (df_ct['crime_rate_per_100k']**0.25 - 1) / 0.25
df_ct = df_ct[df_ct['transformed_CR']>=0]
df_ct['T'] = (df_ct['group']=="Foreigner").astype(int)
df_ct['P'] = (df_ct['year']>=2017).astype(int)
df_ct['T_P'] = df_ct['T'] * df_ct['P']
df_ct['t'] = df_ct['year'] - df_ct['year'].min()
df_ct['T_t'] = df_ct['T'] * df_ct['t']

# 3a) Simple canton panel DiD
mod1 = smf.ols("transformed_CR ~ T_P + C(canton) + C(year) + C(group)", data=df_ct).fit(cov_type='cluster', cov_kwds={'groups': df_ct['canton']})

print("\nCanton-panel DiD (simple)")
print(mod1.summary())
# Out:
# Canton-panel DiD (simple)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         transformed_CR   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     429.1
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           1.41e-23
# Time:                        23:17:20   Log-Likelihood:                -816.30
# No. Observations:                 556   AIC:                             1709.
# Df Residuals:                     518   BIC:                             1873.
# Df Model:                          37
# Covariance Type:              cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        10.3053      0.257     40.085      0.000       9.801      10.809
# C(canton)[T.Appenzell Ausserrhoden]              -1.7192      0.087    -19.694      0.000      -1.890      -1.548
# C(canton)[T.Bern / Berne]                         1.1652   2.76e-14   4.22e+13      0.000       1.165       1.165
# C(canton)[T.Fribourg / Freiburg]                  1.0857   1.79e-14   6.06e+13      0.000       1.086       1.086
# C(canton)[T.Genève]                               2.2119   1.91e-14   1.16e+14      0.000       2.212       2.212
# C(canton)[T.Glarus]                              -1.6474      0.039    -41.854      0.000      -1.725      -1.570
# C(canton)[T.Graubünden / Grigioni / Grischun]    -0.2843   2.63e-14  -1.08e+13      0.000      -0.284      -0.284
# C(canton)[T.Jura]                                -0.9316      0.014    -65.946      0.000      -0.959      -0.904
# C(canton)[T.Luzern]                              -0.6768   2.03e-14  -3.33e+13      0.000      -0.677      -0.677
# C(canton)[T.Neuchâtel]                            2.3848   2.05e-14   1.16e+14      0.000       2.385       2.385
# C(canton)[T.Nidwalden]                           -1.5110      0.100    -15.120      0.000      -1.707      -1.315
# C(canton)[T.Obwalden]                            -1.2188      0.059    -20.542      0.000      -1.335      -1.103
# C(canton)[T.Schaffhausen]                         0.3258      0.020     16.627      0.000       0.287       0.364
# C(canton)[T.Schwyz]                              -1.2876   2.16e-14  -5.97e+13      0.000      -1.288      -1.288
# C(canton)[T.Solothurn]                            0.1338   2.59e-14   5.17e+12      0.000       0.134       0.134
# C(canton)[T.St. Gallen]                           0.2604   2.58e-14   1.01e+13      0.000       0.260       0.260
# C(canton)[T.Thurgau]                             -0.8997   2.25e-14  -3.99e+13      0.000      -0.900      -0.900
# C(canton)[T.Ticino]                               1.1134   2.25e-14   4.94e+13      0.000       1.113       1.113
# C(canton)[T.Uri]                                 -1.6086      0.072    -22.268      0.000      -1.750      -1.467
# C(canton)[T.Valais / Wallis]                      0.4187   2.22e-14   1.89e+13      0.000       0.419       0.419
# C(canton)[T.Vaud]                                 0.8766   2.85e-14   3.07e+13      0.000       0.877       0.877
# C(canton)[T.Zug]                                 -0.9831   2.27e-14  -4.33e+13      0.000      -0.983      -0.983
# C(canton)[T.Zürich]                               2.1278   2.63e-14   8.09e+13      0.000       2.128       2.128
# C(year)[T.2011]                                  -0.3271      0.202     -1.619      0.105      -0.723       0.069
# C(year)[T.2012]                                  -0.3725      0.314     -1.185      0.236      -0.989       0.244
# C(year)[T.2013]                                  -0.6298      0.260     -2.424      0.015      -1.139      -0.121
# C(year)[T.2014]                                  -0.9371      0.258     -3.630      0.000      -1.443      -0.431
# C(year)[T.2015]                                  -1.3428      0.379     -3.546      0.000      -2.085      -0.601
# C(year)[T.2016]                                  -1.1931      0.371     -3.219      0.001      -1.919      -0.467
# C(year)[T.2017]                                  -1.2251      0.382     -3.211      0.001      -1.973      -0.477
# C(year)[T.2018]                                  -0.8225      0.314     -2.622      0.009      -1.437      -0.208
# C(year)[T.2019]                                  -0.5551      0.310     -1.791      0.073      -1.163       0.052
# C(year)[T.2020]                                  -0.1094      0.248     -0.440      0.660      -0.596       0.378
# C(year)[T.2021]                                   0.2822      0.265      1.065      0.287      -0.237       0.801
# C(year)[T.2022]                                  -0.0864      0.334     -0.259      0.796      -0.742       0.569
# C(year)[T.2023]                                   0.1764      0.292      0.605      0.545      -0.395       0.748
# C(group)[T.Swiss]                                -3.6841      0.145    -25.448      0.000      -3.968      -3.400
# T_P                                              -0.1036      0.186     -0.557      0.577      -0.468       0.261
# ==============================================================================
# Omnibus:                       42.971   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.938
# Skew:                          -0.177   Prob(JB):                     4.62e-38
# Kurtosis:                       5.701   Cond. No.                         26.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 37, but rank is 15
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Canton-Panel DiD (parallelity hypothesis relaxed)
#
# same model with $\theta$ variable to treat for parallelity
#
# $\text{transformed\_crime\_rate}_{cgt}
# = \beta\,(T_{g}\times P_{t})
# \;+\;\theta\,(T_{g}\times t)
# \;+\;FE_{c}
# \;+\;FE_{t}
# \;+\;FE_{g}
# \;+\;\varepsilon_{cgt},$
#
# where $t$ is a **linear time index** (year–min(year)).

# %%
mod2 = smf.ols("transformed_CR ~ T_P + T_t + C(group) + C(canton) + C(year)", data=df_ct).fit(cov_type='cluster', cov_kwds={'groups': df_ct['canton']})

print("\nCanton-panel DiD (with trend)")
print(mod2.summary())
# Out:
# Canton-panel DiD (with trend)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         transformed_CR   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     5718.
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           4.93e-36
# Time:                        23:17:20   Log-Likelihood:                -816.22
# No. Observations:                 556   AIC:                             1710.
# Df Residuals:                     517   BIC:                             1879.
# Df Model:                          38
# Covariance Type:              cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        10.3320      0.260     39.671      0.000       9.822      10.842
# C(group)[T.Swiss]                                -3.7374      0.154    -24.283      0.000      -4.039      -3.436
# C(canton)[T.Appenzell Ausserrhoden]              -1.7192      0.087    -19.675      0.000      -1.890      -1.548
# C(canton)[T.Bern / Berne]                         1.1652   8.12e-14   1.44e+13      0.000       1.165       1.165
# C(canton)[T.Fribourg / Freiburg]                  1.0857   7.83e-14   1.39e+13      0.000       1.086       1.086
# C(canton)[T.Genève]                               2.2119    7.1e-14   3.12e+13      0.000       2.212       2.212
# C(canton)[T.Glarus]                              -1.6474      0.039    -41.813      0.000      -1.725      -1.570
# C(canton)[T.Graubünden / Grigioni / Grischun]    -0.2843   7.86e-14  -3.62e+12      0.000      -0.284      -0.284
# C(canton)[T.Jura]                                -0.9316      0.014    -65.882      0.000      -0.959      -0.904
# C(canton)[T.Luzern]                              -0.6768   8.12e-14  -8.33e+12      0.000      -0.677      -0.677
# C(canton)[T.Neuchâtel]                            2.3848   8.13e-14   2.93e+13      0.000       2.385       2.385
# C(canton)[T.Nidwalden]                           -1.5110      0.100    -15.105      0.000      -1.707      -1.315
# C(canton)[T.Obwalden]                            -1.2188      0.059    -20.522      0.000      -1.335      -1.102
# C(canton)[T.Schaffhausen]                         0.3258      0.020     16.611      0.000       0.287       0.364
# C(canton)[T.Schwyz]                              -1.2876   7.93e-14  -1.62e+13      0.000      -1.288      -1.288
# C(canton)[T.Solothurn]                            0.1338   7.71e-14   1.74e+12      0.000       0.134       0.134
# C(canton)[T.St. Gallen]                           0.2604   8.05e-14   3.23e+12      0.000       0.260       0.260
# C(canton)[T.Thurgau]                             -0.8997   7.93e-14  -1.13e+13      0.000      -0.900      -0.900
# C(canton)[T.Ticino]                               1.1134    7.5e-14   1.48e+13      0.000       1.113       1.113
# C(canton)[T.Uri]                                 -1.6086      0.072    -22.246      0.000      -1.750      -1.467
# C(canton)[T.Valais / Wallis]                      0.4187   7.49e-14   5.59e+12      0.000       0.419       0.419
# C(canton)[T.Vaud]                                 0.8766   8.13e-14   1.08e+13      0.000       0.877       0.877
# C(canton)[T.Zug]                                 -0.9831   7.94e-14  -1.24e+13      0.000      -0.983      -0.983
# C(canton)[T.Zürich]                               2.1278   7.62e-14   2.79e+13      0.000       2.128       2.128
# C(year)[T.2011]                                  -0.3182      0.213     -1.497      0.134      -0.735       0.098
# C(year)[T.2012]                                  -0.3548      0.322     -1.101      0.271      -0.986       0.276
# C(year)[T.2013]                                  -0.6031      0.292     -2.064      0.039      -1.176      -0.030
# C(year)[T.2014]                                  -0.9016      0.254     -3.548      0.000      -1.400      -0.404
# C(year)[T.2015]                                  -1.2984      0.393     -3.306      0.001      -2.068      -0.529
# C(year)[T.2016]                                  -1.1398      0.382     -2.982      0.003      -1.889      -0.391
# C(year)[T.2017]                                  -1.2262      0.383     -3.204      0.001      -1.976      -0.476
# C(year)[T.2018]                                  -0.8148      0.311     -2.623      0.009      -1.424      -0.206
# C(year)[T.2019]                                  -0.5385      0.307     -1.755      0.079      -1.140       0.063
# C(year)[T.2020]                                  -0.0839      0.250     -0.335      0.738      -0.575       0.407
# C(year)[T.2021]                                   0.3165      0.289      1.095      0.273      -0.250       0.883
# C(year)[T.2022]                                  -0.0432      0.342     -0.126      0.899      -0.713       0.627
# C(year)[T.2023]                                   0.2285      0.292      0.783      0.433      -0.343       0.800
# T_P                                               0.0231      0.387      0.060      0.952      -0.735       0.781
# T_t                                              -0.0178      0.045     -0.398      0.691      -0.105       0.070
# ==============================================================================
# Omnibus:                       42.969   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.802
# Skew:                          -0.178   Prob(JB):                     4.94e-38
# Kurtosis:                       5.700   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 38, but rank is 16
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Canton-Specific DiD Regression Explanation
#
# We estimate the following model:
#
# $\text{transformed\_crime\_rate}_{cgt} = FE_{g}
# \;+\;FE_{t}
# \;+\;FE_{c}
# \;+\;\sum_{c}\beta_{c}\,\Bigl(\mathbf{1}\{\text{canton}=c\}\times T_{g} \times P_{t}\Bigr)
# \;+\;\varepsilon_{cgt},$

# %%
mod3 = smf.ols("transformed_CR ~ C(group) + C(year) + C(canton) + C(canton):T_P", data=df_ct).fit()

print(mod3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         transformed_CR   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     40.96
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):          5.94e-155
# Time:                        23:17:20   Log-Likelihood:                -796.84
# No. Observations:                 556   AIC:                             1714.
# Df Residuals:                     496   BIC:                             1973.
# Df Model:                          59
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          10.3237      0.293     35.281      0.000       9.749      10.899
# C(group)[T.Swiss]                                  -3.6841      0.130    -28.288      0.000      -3.940      -3.428
# C(year)[T.2011]                                    -0.3311      0.244     -1.359      0.175      -0.810       0.148
# C(year)[T.2012]                                    -0.3574      0.242     -1.477      0.140      -0.833       0.118
# C(year)[T.2013]                                    -0.6304      0.252     -2.500      0.013      -1.126      -0.135
# C(year)[T.2014]                                    -0.8887      0.240     -3.698      0.000      -1.361      -0.417
# C(year)[T.2015]                                    -1.2941      0.243     -5.322      0.000      -1.772      -0.816
# C(year)[T.2016]                                    -1.1854      0.244     -4.855      0.000      -1.665      -0.706
# C(year)[T.2017]                                    -1.1890      0.264     -4.499      0.000      -1.708      -0.670
# C(year)[T.2018]                                    -0.7988      0.261     -3.056      0.002      -1.312      -0.285
# C(year)[T.2019]                                    -0.5225      0.261     -2.004      0.046      -1.035      -0.010
# C(year)[T.2020]                                    -0.0967      0.256     -0.377      0.706      -0.600       0.407
# C(year)[T.2021]                                     0.2997      0.253      1.183      0.237      -0.198       0.797
# C(year)[T.2022]                                    -0.0560      0.255     -0.219      0.827      -0.558       0.446
# C(year)[T.2023]                                     0.1965      0.253      0.776      0.438      -0.301       0.694
# C(canton)[T.Appenzell Ausserrhoden]                -1.8931      0.503     -3.763      0.000      -2.882      -0.905
# C(canton)[T.Bern / Berne]                           0.8269      0.331      2.495      0.013       0.176       1.478
# C(canton)[T.Fribourg / Freiburg]                    1.0301      0.331      3.108      0.002       0.379       1.681
# C(canton)[T.Genève]                                 2.2531      0.331      6.798      0.000       1.602       2.904
# C(canton)[T.Glarus]                                -1.7421      0.364     -4.780      0.000      -2.458      -1.026
# C(canton)[T.Graubünden / Grigioni / Grischun]      -0.4883      0.331     -1.473      0.141      -1.139       0.163
# C(canton)[T.Jura]                                  -0.7626      0.340     -2.240      0.026      -1.432      -0.094
# C(canton)[T.Luzern]                                -0.6809      0.331     -2.055      0.040      -1.332      -0.030
# C(canton)[T.Neuchâtel]                              2.0363      0.331      6.144      0.000       1.385       2.687
# C(canton)[T.Nidwalden]                             -1.3826      0.474     -2.919      0.004      -2.313      -0.452
# C(canton)[T.Obwalden]                              -1.7205      0.451     -3.819      0.000      -2.606      -0.835
# C(canton)[T.Schaffhausen]                           0.2265      0.341      0.665      0.506      -0.443       0.896
# C(canton)[T.Schwyz]                                -1.1499      0.331     -3.470      0.001      -1.801      -0.499
# C(canton)[T.Solothurn]                              0.1538      0.331      0.464      0.643      -0.497       0.805
# C(canton)[T.St. Gallen]                             0.2201      0.331      0.664      0.507      -0.431       0.871
# C(canton)[T.Thurgau]                               -0.9175      0.331     -2.768      0.006      -1.569      -0.266
# C(canton)[T.Ticino]                                 1.1405      0.331      3.441      0.001       0.489       1.792
# C(canton)[T.Uri]                                   -2.0130      0.594     -3.390      0.001      -3.179      -0.846
# C(canton)[T.Valais / Wallis]                        0.3457      0.331      1.043      0.297      -0.305       0.997
# C(canton)[T.Vaud]                                   0.9422      0.331      2.843      0.005       0.291       1.593
# C(canton)[T.Zug]                                   -0.7416      0.331     -2.238      0.026      -1.393      -0.090
# C(canton)[T.Zürich]                                 2.2046      0.331      6.652      0.000       1.553       2.856
# C(canton)[Aargau]:T_P                              -0.2596      0.492     -0.528      0.598      -1.227       0.707
# C(canton)[Appenzell Ausserrhoden]:T_P               0.4042      0.895      0.452      0.652      -1.353       2.162
# C(canton)[Bern / Berne]:T_P                         1.0933      0.492      2.222      0.027       0.126       2.060
# C(canton)[Fribourg / Freiburg]:T_P                 -0.0372      0.492     -0.076      0.940      -1.004       0.930
# C(canton)[Genève]:T_P                              -0.4242      0.492     -0.862      0.389      -1.391       0.543
# C(canton)[Glarus]:T_P                               0.1084      0.576      0.188      0.851      -1.023       1.239
# C(canton)[Graubünden / Grigioni / Grischun]:T_P     0.5562      0.492      1.130      0.259      -0.411       1.523
# C(canton)[Jura]:T_P                                -0.8682      0.498     -1.744      0.082      -1.846       0.110
# C(canton)[Luzern]:T_P                              -0.2433      0.492     -0.494      0.621      -1.210       0.724
# C(canton)[Neuchâtel]:T_P                            1.1341      0.492      2.305      0.022       0.167       2.101
# C(canton)[Nidwalden]:T_P                           -0.6359      0.759     -0.838      0.402      -2.126       0.854
# C(canton)[Obwalden]:T_P                             1.2607      0.675      1.867      0.062      -0.066       2.587
# C(canton)[Schaffhausen]:T_P                         0.1144      0.498      0.230      0.818      -0.863       1.092
# C(canton)[Schwyz]:T_P                              -0.8107      0.492     -1.647      0.100      -1.778       0.156
# C(canton)[Solothurn]:T_P                           -0.3397      0.492     -0.690      0.490      -1.307       0.627
# C(canton)[St. Gallen]:T_P                          -0.0983      0.492     -0.200      0.842      -1.065       0.869
# C(canton)[Thurgau]:T_P                             -0.1886      0.492     -0.383      0.702      -1.156       0.778
# C(canton)[Ticino]:T_P                              -0.3682      0.492     -0.748      0.455      -1.335       0.599
# C(canton)[Uri]:T_P                                  0.9756      0.945      1.032      0.302      -0.881       2.833
# C(canton)[Valais / Wallis]:T_P                      0.0325      0.492      0.066      0.947      -0.934       0.999
# C(canton)[Vaud]:T_P                                -0.5218      0.492     -1.060      0.290      -1.489       0.445
# C(canton)[Zug]:T_P                                 -1.2257      0.492     -2.491      0.013      -2.193      -0.259
# C(canton)[Zürich]:T_P                              -0.5670      0.492     -1.152      0.250      -1.534       0.400
# ==============================================================================
# Omnibus:                       52.614   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.785
# Skew:                          -0.284   Prob(JB):                     1.54e-49
# Kurtosis:                       6.063   Cond. No.                         31.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Event study (final test)
#
# $
# \text{transformed\_crime\_rate}_{cgt}
# = FE_{c} + FE_{t} + FE_{g}
# + \sum_{\substack{k=-5 \\ k\neq -1}}^{5}
#     \beta_{k}\,\bigl[\mathbf{1}(t-2017 = k)\times D_{g}\bigr]
# + \varepsilon_{igt}
# $

# %%
df_ct = df_ct.copy()

# 1) Ensure year is int
df_ct['year'] = df_ct['year'].astype(int)

df_ct['treat'] = (df_ct['group'] == "Foreigner").astype(int)
print("Treated obs:", df_ct['treat'].sum(), "/", len(df_ct))

lead_cols = []
for k in range(-7, 7):
    if k == -1: 
        continue
    suffix = f"m{abs(k)}" if k < 0 else f"p{k}"
    name   = f"lead_{suffix}"
    df_ct[name] = ((df_ct['year'] - 2017) == k).astype(int) * df_ct['treat']
    print(f"{name}: {df_ct[name].sum()} treated obs")
    lead_cols.append(name)

# Event-study regression
formula = "transformed_CR ~ " + " + ".join(lead_cols) + " + C(canton)+ C(group) + C(year)"
mod_es = smf.ols(formula, data=df_ct).fit(
    cov_type="cluster", cov_kwds={"groups": df_ct["canton"]})
print(mod_es.summary())
# Out:
# Treated obs: 278 / 556
# lead_m7: 20 treated obs
# lead_m6: 19 treated obs
# lead_m5: 20 treated obs
# lead_m4: 17 treated obs
# lead_m3: 21 treated obs
# lead_m2: 20 treated obs
# lead_p0: 18 treated obs
# lead_p1: 19 treated obs
# lead_p2: 19 treated obs
# lead_p3: 21 treated obs
# lead_p4: 22 treated obs
# lead_p5: 21 treated obs
# lead_p6: 22 treated obs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         transformed_CR   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     131.7
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           1.46e-18
# Time:                        23:17:20   Log-Likelihood:                -811.37
# No. Observations:                 556   AIC:                             1723.
# Df Residuals:                     506   BIC:                             1939.
# Df Model:                          49
# Covariance Type:              cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         9.9595      0.451     22.077      0.000       9.075      10.844
# C(canton)[T.Appenzell Ausserrhoden]              -1.7192      0.088    -19.464      0.000      -1.892      -1.546
# C(canton)[T.Bern / Berne]                         1.1652   6.19e-14   1.88e+13      0.000       1.165       1.165
# C(canton)[T.Fribourg / Freiburg]                  1.0857   5.52e-14   1.97e+13      0.000       1.086       1.086
# C(canton)[T.Genève]                               2.2119   5.57e-14   3.97e+13      0.000       2.212       2.212
# C(canton)[T.Glarus]                              -1.6474      0.040    -41.366      0.000      -1.725      -1.569
# C(canton)[T.Graubünden / Grigioni / Grischun]    -0.2843    5.9e-14  -4.82e+12      0.000      -0.284      -0.284
# C(canton)[T.Jura]                                -0.9316      0.014    -65.178      0.000      -0.960      -0.904
# C(canton)[T.Luzern]                              -0.6768   5.34e-14  -1.27e+13      0.000      -0.677      -0.677
# C(canton)[T.Neuchâtel]                            2.3848   5.85e-14   4.07e+13      0.000       2.385       2.385
# C(canton)[T.Nidwalden]                           -1.5110      0.101    -14.943      0.000      -1.709      -1.313
# C(canton)[T.Obwalden]                            -1.2188      0.060    -20.303      0.000      -1.336      -1.101
# C(canton)[T.Schaffhausen]                         0.3258      0.020     16.434      0.000       0.287       0.365
# C(canton)[T.Schwyz]                              -1.2876    5.9e-14  -2.18e+13      0.000      -1.288      -1.288
# C(canton)[T.Solothurn]                            0.1338   5.61e-14   2.39e+12      0.000       0.134       0.134
# C(canton)[T.St. Gallen]                           0.2604   6.07e-14   4.29e+12      0.000       0.260       0.260
# C(canton)[T.Thurgau]                             -0.8997   6.04e-14  -1.49e+13      0.000      -0.900      -0.900
# C(canton)[T.Ticino]                               1.1134   6.45e-14   1.73e+13      0.000       1.113       1.113
# C(canton)[T.Uri]                                 -1.6086      0.073    -22.009      0.000      -1.752      -1.465
# C(canton)[T.Valais / Wallis]                      0.4187   6.31e-14   6.64e+12      0.000       0.419       0.419
# C(canton)[T.Vaud]                                 0.8766   6.48e-14   1.35e+13      0.000       0.877       0.877
# C(canton)[T.Zug]                                 -0.9831   6.29e-14  -1.56e+13      0.000      -0.983      -0.983
# C(canton)[T.Zürich]                               2.1278   5.77e-14   3.69e+13      0.000       2.128       2.128
# C(group)[T.Swiss]                                -3.3887      0.348     -9.736      0.000      -4.071      -2.706
# C(year)[T.2011]                                  -0.3917      0.173     -2.264      0.024      -0.731      -0.053
# C(year)[T.2012]                                  -0.4122      0.287     -1.434      0.151      -0.975       0.151
# C(year)[T.2013]                                  -0.8137      0.234     -3.484      0.000      -1.272      -0.356
# C(year)[T.2014]                                  -0.6822      0.236     -2.889      0.004      -1.145      -0.219
# C(year)[T.2015]                                  -1.1980      0.381     -3.143      0.002      -1.945      -0.451
# C(year)[T.2016]                                  -0.9949      0.427     -2.332      0.020      -1.831      -0.159
# C(year)[T.2017]                                  -1.0694      0.363     -2.946      0.003      -1.781      -0.358
# C(year)[T.2018]                                  -0.8027      0.401     -2.001      0.045      -1.589      -0.016
# C(year)[T.2019]                                  -0.5207      0.308     -1.693      0.090      -1.123       0.082
# C(year)[T.2020]                                   0.0426      0.268      0.159      0.874      -0.483       0.568
# C(year)[T.2021]                                   0.3101      0.253      1.225      0.221      -0.186       0.806
# C(year)[T.2022]                                   0.1182      0.284      0.416      0.677      -0.439       0.675
# C(year)[T.2023]                                  -0.0402      0.338     -0.119      0.905      -0.703       0.623
# lead_m7                                           0.3964      0.333      1.190      0.234      -0.257       1.049
# lead_m6                                           0.5256      0.423      1.244      0.214      -0.303       1.354
# lead_m5                                           0.4756      0.330      1.440      0.150      -0.172       1.123
# lead_m4                                           0.7643      0.477      1.601      0.109      -0.171       1.700
# lead_m3                                          -0.1135      0.418     -0.271      0.786      -0.934       0.707
# lead_m2                                           0.1069      0.338      0.316      0.752      -0.556       0.770
# lead_p0                                          -0.0187      0.366     -0.051      0.959      -0.737       0.699
# lead_p1                                           0.2532      0.518      0.488      0.625      -0.763       1.269
# lead_p2                                           0.2239      0.559      0.401      0.688      -0.871       1.319
# lead_p3                                          -0.0113      0.326     -0.034      0.972      -0.651       0.628
# lead_p4                                           0.2369      0.500      0.474      0.635      -0.742       1.216
# lead_p5                                          -0.1166      0.539     -0.217      0.829      -1.172       0.939
# lead_p6                                           0.7260      0.480      1.514      0.130      -0.214       1.666
# ==============================================================================
# Omnibus:                       41.663   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.168
# Skew:                          -0.217   Prob(JB):                     1.49e-33
# Kurtosis:                       5.517   Cond. No.                         36.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 49, but rank is 22
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ## Counterfactual graph of the DiD

# %%
# Build a “counterfactual” dataset where Foreigner keeps its pre-treatment trend:
df_ct_cf = df_ct.copy()
# zero out the post dummy so the Foreigner×Post jump vanishes
df_ct_cf['T_P'] = 0

# keep the group‐specific trend term intact (so slope continues)
# T_t is just time × Foreigner, so it stays

# Predict both actual and counterfactual paths
df_ct['f_actual'] = mod2.predict(df_ct)
df_ct_cf['f_cf']    = mod2.predict(df_ct_cf)

# Aggregate to year × group means
agg = (
    df_ct
    .assign(f_cf=df_ct_cf['f_cf'])
    .groupby(['group','year'])
    .agg(obs_rate=('transformed_CR','mean'),
         fit_actual=('f_actual','mean'),
         fit_cf    =('f_cf','mean'))
    .reset_index())

plt.figure(figsize=(10,6))

for grp, color in [('Swiss','red'), ('Foreigner','blue')]:
    sub = df_ct[df_ct['group'] == grp]
    plt.scatter(sub['year'], sub['transformed_CR'],
                color=color, alpha=0.3, s=10,
                label=f'Observed: {grp}')

for grp, color in [('Swiss','red'), ('Foreigner','blue')]:
    sub = agg[agg['group']==grp]
    plt.plot(sub['year'], sub['fit_actual'], color=color, lw=2,
             label=f'Fitted actual: {grp}')
    if grp=='Foreigner':
        plt.plot(sub['year'], sub['fit_cf'], color=color, lw=2, ls='--',
                 label='Counterfactual (parallel trend)')

plt.axvline(2017, color='black', ls=':', lw=1.5, label='Treatment (2017)')

plt.xlabel('Year')
plt.ylabel('Transformed crime rate')
plt.title('DiD with group‐specific trend: Actual vs. Parallel‐trend CF')
plt.legend()
plt.tight_layout()
plt.savefig("/Users/souhil/Desktop/Courses/Recherche Empirique/Final/did_graph_boxcox.png", dpi=300, bbox_inches='tight')  
plt.show()
